# %%
conda install selenium
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
from selenium import webdriver
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from itertools import count
import time

# %%
driver = webdriver.Chrome('D:\chatbot\chromedriver.exe')
driver.get('https://uwins.ulsan.ac.kr/Default.aspx')

# %%
driver.find_element_by_id('CP1_id').send_keys('ogong5267')
driver.find_element_by_id('CP1_pw').send_keys('alfhckwrl7-')

# %%
driver.find_element_by_id('CP1_btnLogin').click()

# %%
time.sleep(1)

# %%
driver.get('https://uwins.ulsan.ac.kr/JBGJ/D/MID01S.aspx?current_page=1&keyfield=1&keyword=%ec%88%98%ea%b0%95%ec%8b%a0%ec%b2%ad&Buseo=&MenuID=MID01S!1')

# %%
html = driver.page_source

# %%
soupData = BeautifulSoup(html, 'html.parser')
print(soupData.prettify())
# Out:
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="no-cache" http-equiv="Pragma"/>
#   <meta content="no-cache" http-equiv="Cache-control"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="blendTrans(Duration=0)" http-equiv="Page-Enter"/>
#   <meta content="blendTrans(Duration=0)" http-equiv="Page-Exit"/>
#   <meta content="울산대학교 학생포털, UWINS" name="keywords"/>
#   <meta content="울산대학교 학생포털(UWINS)" name="description"/>
#   <link href="/Common/Css/UWINS_Style.css" rel="stylesheet" type="text/css"/>
#   <link href="/Common/Css/Main.css" rel="stylesheet" type="text/css"/>
#   <link href="/Common/Css/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <link href="/Common/Images/uou.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script src="/Common/Js/jquery-1.11.2.min.js" type="text/javascript">
#   </script>
# ...

# %%
find_tds = soupData.findAll('td')

# %%
find_tds[:]
# Out:
# [<td class="textWrap Center"> <span class="ico btn_m01">Q</span> </td>,
#  <td class="textWrap Center">
#  <span id="CP1_iuwgList_seq_0">21714</span>
#  </td>,
#  <td class="textWrap Left">
#  <a href="MID01S_02.aspx?MenuID=MID01S!1&amp;seq=21714&amp;keyfield=1&amp;keyword=수강신청&amp;current_page=1&amp;buseo_nm=" id="CP1_iuwgList_jemog_0">군휴학중 수강신청</a>
#  </td>,
#  <td class="textWrap Center">
#  <span id="CP1_iuwgList_jagseongja_nm_0">김수연</span>
#  </td>,
#  <td class="textWrap Center">
#  <span id="CP1_iuwgList_buseo_nm_0">학사관리팀</span>
#  </td>,
#  <td class="textWrap Center">
#  <span id="CP1_iuwgList_dt_0">2021.10.01</span>
#  </td>,
#  <td class="textWrap Center">
#  <span id="CP1_iuwgList_johoe_cnt_0">27</span>
#  </td>,
#  <td class="textWrap Center"> <span class="ico btn_m02">A</span> </td>,
#  <td class="textWrap Center">
#  <span id="CP1_iuwgList_seq_1">21602</span>
#  </td>,
#  <td class="textWrap Left">
# ...

# %%
result=[]
for ques_td in find_tds[1:]:
    ques_tag = ques_td.find('span',{'class':'ico btn_m02'})
    ques_tag.get_text()
    ques_content = main.find('a').text
    ques_department = qna.find('span',attrs={'id':'CP1_iuwgList_buseo'}).text
    result.append(ques_tag + ques_content + ques_department)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-f51f82118ce8> in <module>
#       2 for ques_td in find_tds[1:]:
#       3     ques_tag = ques_td.find('span',{'class':'ico btn_m02'})
# ----> 4     ques_tag.get_text()
#       5     ques_content = main.find('a').text
#       6     ques_department = qna.find('span',attrs={'id':'CP1_iuwgList_buseo'}).text
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
result
# Out:
# []
